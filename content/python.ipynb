# %%
import pandas as pd
import duckdb

from io import StringIO
from IPython.display import display


ads_data = """\
ad_id	campaign_id	status
1	1	active
2	1	inactive
3	1	active
4	2	active
5	2	inactive
6	2	inactive
"""

ads = pd.read_csv(StringIO(ads_data), sep="\t")

events_data = """\
event_id	ad_id	source	event_type	date	hour
xAbcd3	1	iOS	impression	01/12/2020	13
bf3VEc	1	iOS	impression	01/12/2020	15
bfE4gc	1	Android	click	14/12/2020	7
hTeGs5	3	Web	conversion	01/12/2020	12
g5ht7f	3	Android	click	07/12/2020	23
if5s3v	4	Web	conversion	14/12/2020	8
"""

events = pd.read_csv(StringIO(events_data), sep="\t")


display(ads)
display(events)
# Out:
#    ad_id  campaign_id    status
# 0      1            1    active
# 1      2            1  inactive
# 2      3            1    active
# 3      4            2    active
# 4      5            2  inactive
# 5      6            2  inactive
#   event_id  ad_id   source  event_type        date  hour
# 0   xAbcd3      1      iOS  impression  01/12/2020    13
# 1   bf3VEc      1      iOS  impression  01/12/2020    15
# 2   bfE4gc      1  Android       click  14/12/2020     7
# 3   hTeGs5      3      Web  conversion  01/12/2020    12
# 4   g5ht7f      3  Android       click  07/12/2020    23
# 5   if5s3v      4      Web  conversion  14/12/2020     8

# %%
# Answer with Pandas
ads["status"]
# Out:
# 0      active
# 1    inactive
# 2      active
# 3      active
# 4    inactive
# 5    inactive
# Name: status, dtype: object

# %% [markdown]
# - Quel est le nombre de campagnes actives? (une campagne est active si au moins un ad est actif)
# - Creer un dataframe contenant tous les events de type clicks ou impression
# - Creer un dataframe contenant le nombre d'events par date
# - Creer un dataframe contenant le nombre d'events par campagne
# - Creer un dataframe contenant le nombre d'impression, click et conversion par campagne
